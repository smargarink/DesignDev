# %% [markdown]
# # Stage One: Import the libraries and Scrape your Page
#
# 1. Using documentation from https://towardsdatascience.com/web-scraping-metacritic-reviews-using-beautifulsoup-63801bbe200e and BeautifulSoup module to import library and scrape page.
# 2. Find queer game to review - go to user review section.
# 3. Use BeautifulSoup as a parser

# %%
# involving BeautifulSoup and Pandas to organize data in a more structured way. 

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#using Beautifulsoup as parser to read/scrub site

url = 'https://www.metacritic.com/game/playstation-4/life-is-strange-true-colors/user-reviews'

user_agent = {'User-agent': 'Mozilla/5.0'}
response = requests.get(url, headers = user_agent)

soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# # Stage Two: Define an Empty Dictionary Reflecting the Data Categories
# 1. Set dictionary with speicifc categories to pull from site

# %%
#pull specific data from site, set peramaters as a dictionary 


review_dict = {'name':[], 'date':[], 'rating':[], 'review':[]}

# %% [markdown]
# # Stage Three: Loop through and Store Structured Data

# %%
#look for review_content tags since every user review has this tag
 
for review in soup.find_all('div', class_='review_content'): 
    if review.find('div', class_='name') == None:
        break 
    review_dict['name'].append(review.find('div', class_='name').find('a').text)
    review_dict['date'].append(review.find('div', class_='date').text)
    review_dict['rating'].append(review.find('div', class_='review_grade').find_all('div')[0].text)
    if review.find('span', class_='blurb blurb_expanded'): 
        review_dict['review'].append(review.find('span', class_='blurb blurb_expanded').text)
        print(review.find('span', class_='blurb blurb_expanded').text)
    elif review.find('div',class_='review_body').find('span') == None:
        review_dict['review'].append('No review text.')
        print("No review")
    else:
        review_dict['review'].append(review.find('div',class_='review_body').find('span').text)
        print(review.find('div',class_='review_body').find('span').text)
# Out:
# This had potential to be the best Life is Strange game. There were times where I felt like that this was going to be the best but at the end it disappointed because let me tell you one thing. It's basically a copy of the First Life is Strange. I appreciate the graphics, the soundtrack and the characters but the plot is kinda disappointing and it's really short. This game may be better than Life is Strange 2 and Before the storm, but not as good as the very first one. I suggest to wait for a price drop. So much potential but wasted
#  P.S. The "review bombing" thing is way blown out of proportion. This is not a major title & at the time of writing, there're only ~50 reviews and negative "review bombs" are less than 10 so it was probably a few people. There are twice more people complaining about "review bombing" than people who are supposedly doing it. And all these media coverage...uh, do you really want to call maybe 2-3 people complaining "review bombing"?
# I just finished playing this game and i have mixed reaction about it... this game is a little bit slow some times you may feels boor while playing this game but Don't stop playing.... because this game has a twist in the storyline that blowups youre miend.. i am going with 7 out 10 stars for this game. #GameIsLove
# The weakest and most boring game in the series. The plot is boring and not intriguing. All characters are boring and dull. Twin Mirror turned out to be much more interesting. The most memorable thing in this game is the Shu-Shu plush toy.
# You will experience an interesting story that will send you on an emotional roller coaster. You will want to finish it with one breath and still entertain you for at least 10 to 15 hours. Compared to any role-playing game, game time lags a bit, but this is an adventure as it should be, here you can make up for it with an even richer experience - both pictorial, musical and story. Free Tibet. I hope that the developers will not give in to the pressure of the communist regime that rules in totality China
# Loved this game! Such a beautiful story. I prefer this game over lis 2 and before the storm but i still prefer the original game but that might be due to nostalgia.Def worthy checking out
# Игра которая хочет в кино. Но откровенно скучно, в играх прежде всего важен геймплей, я играю а не смотрю. Отвратительно и скучно.
# Boring and really short. Buy something better or wait this is too expensive for what you get.
# True Colors is a return to glory for the Life is Strange franchise. It brings back the charm of a single small town to experience as well as returning to actually having likable characters that restored my faith in the series after the dumpster fire that was Season 2. While it wasn't quite as good as Season 1 it was much better than Season 2 by returning to what made Season 1 great and even threw in some interesting new features that made True Colors a truly enjoyable experience.
# I have to say that this game is a Masterpiece. Best in the whole series by a longshot and definitelly my favourite game this year. It is in my top 2 games of all times as well. Everything was just awesome. The story, the characters and their development, the game play, the dialogues, the soundtrack and sound effects, the graphics, just everything. It was also very emotional and relaxing to play as well. The only thing i would love if it was a bit longer. But other than that I can say that this game is just perfect.

# %% [markdown]
# # Stage Four: Convert from Dictionary to DataFrame and Display

# %%
#Covery from dictionaryto data frame

ac_reviews = pd.DataFrame(review_dict)

# %%
#and display

ac_reviews
# Out:
#                name          date rating  \
# 0             eljon  Sep 12, 2021      7
# 1             MACBX  Sep 13, 2021      7
# 2            Sridev  Sep 14, 2021      7
# 3          Nickolay  Sep 14, 2021      6
# 4        Halfloe_CZ  Sep 14, 2021      9
# 5          mononyan  Sep 12, 2021      9
# 6    DanielGorskikh  Sep 24, 2021      0
# 7        LastHope17  Sep 13, 2021      3
# 8            Racer1  Sep 13, 2021      3
# 9      LoneWolf8021  Sep 11, 2021      9
# 10             Kold  Sep 12, 2021      4
# 11         mike4156  Sep 16, 2021      2
# 12   super_absorber  Sep 16, 2021      2
# 13    Lostforever77  Sep 12, 2021     10
# 14     MeroOtaku121  Sep 17, 2021     10
# 15          Celerex  Sep 12, 2021     10
# 16           Gelkaz  Sep 12, 2021     10
# 17        pieniadz0  Sep 12, 2021      8
# 18        infraphys  Sep 12, 2021      1
# 19          cheemss  Sep 19, 2021      0
# 20      TheTrashBoi  Sep 11, 2021     10
# 21     CrazyMrLahey  Sep 12, 2021     10
# 22          xNAMx10  Sep 11, 2021     10
# 23         FuyuNoKo  Sep 20, 2021      3
# 24         gurkamar  Sep 12, 2021      9
# 25         Valarius  Sep 12, 2021      9
# 26       Mohammadof  Sep 12, 2021      8
# 27         kon_grin  Sep 13, 2021     10
# 28  somberdarkness0  Sep 16, 2021      9
# 29        Zumbie101  Sep 17, 2021      8
# 30       Greenman88  Sep 12, 2021     10
# 31         MENSCH69  Sep 12, 2021      9
# 32           evicab  Sep 18, 2021     10
# 33        cynthiayo  Sep 19, 2021     10
# 34    oneminutemore  Sep 20, 2021      8
# 35        Onestlaaa  Sep 27, 2021      7
# 36          Teleman  Oct  3, 2021      0
# 37        onycolo39  Sep 23, 2021     10
# 38     Evenstar1985  Oct  2, 2021      9
# 39    LesMiserables  Oct  2, 2021      6
# 40         ismentis  Sep 29, 2021      9
# 41         escaflon  Sep 21, 2021      3
# 42    LikeToBeBossy  Sep 23, 2021     10
# 43        Akkuarius  Sep 23, 2021      8
# 44              IOI  Sep 24, 2021      8
# 45    Hawkeye112196  Sep 29, 2021      9
# 46        Gregy2005  Sep 28, 2021     10
#
#                                                review
# 0   This had potential to be the best Life is Stra...
# 1   Played the original LiS before and never seque...
# 2   I just finished playing this game and i have m...
# 3   The weakest and most boring game in the series...
# 4   You will experience an interesting story that ...
# 5   Loved this game! Such a beautiful story. I pre...
# 6   Игра которая хочет в кино. Но откровенно скучн...
# 7   Boring and really short. Buy something better ...
# 8   So booring story, without normal gameplay. If ...
# 9   Such a good game.  Definitely brought back a l...
# 10  The story is relatively boring and presses on ...
# 11  hardly a good game , its 70% cutscene and a po...
# 12  This is a boring game. The story is C- grade. ...
# 13  Choices matterSoundtrack and story awesomeChar...
# 14  It was the first game that make me cry, the st...
# 15  LiS 1 and its DLC are among the best experienc...
# 16  10/10. Игры превзошла даже самые смелые ожидан...
# 17  It felt kinda slow at the beginning, but as th...
# 18  al inicio el juego parece interesante el prime...
# 19  boring, not worth the price, non-intriguing st...
# 20  An immense improvement over Life is Strange 2,...
# 21  This game is fantastic. Game is a solid pick u...
# 22  AMAZING GAME, Life is Strange 2 is still bette...
# 23  Dieses Spiel ist wirklich mit Abstand das gene...
# 24  The twists and turns weren't as good as previo...
# 25  Almost as good as the first Life is strange. T...
# 26  Way Better than life is strange 2 if I'm wanna...
# 27  To be honest, some of my expectations were not...
# 28  Cute, fun game. If you enjoyed the original Li...
# 29  Pretty chill game, some parts were a bit slow ...
# 30  All politics aside this is an amazing game wit...
# 31  I love the LiS franchise (apart from the secon...
# 32  This is one of the best stories in the series....
# 33  honestly such a good game\rkind of open world\...
# 34  Specially registered here to leave your review...
# 35  J'ai l'impression que ce jeu contrairement a s...
# 36  Garbage plot full of unconvincing events and s...
# 37  great narrative, great graphics. a great game ...
# 38  Great game, the facial expression animations w...
# 39  At this point it would be foolish to walk into...
# 40  I love Life is strange series and this is almo...
# 41  Тупой гемплей, некрасивая главная героиня. Оче...
# 42  Life Is Strange: True Colors will be my favori...
# 43  The games is pretty good. It has it flaws but ...
# 44  The graphics are stunning, and the facial expr...
# 45  True Colors is a return to glory for the Life ...
# 46  I have to say that this game is a Masterpiece....

# %% [markdown]
# # Stage Five: Plot some Aspect of the Data
# 1. create a bar graph of each rating

# %%
#plot ratings

ac_reviews['rating'].value_counts().plot(kind='bar', figsize=(7, 6), rot=0, title="amount of each rating")
# Out:
# <AxesSubplot:title={'center':'amount of each rating'}>

# %% [markdown]
# # Bonus Stage: Add On

# %%
V = {1, 2, 3, 4, 5}
E = {(1, 2), (1, 4), (2, 5), (3, 4), (4, 5)}

import networkx as nx

G = nx.Graph()
G.add_nodes_from(V)
G.add_edges_from(E)

import matplotlib.pyplot as plt

nx.draw_networkx(G, font_color="white")
plt.axis('off')
# Out:
# (-1.1840482842851698,
#  0.9368890870010714,
#  -0.6797535568925721,
#  0.7746985976872088)

# %%
from BeautifulSoup import BeautifulStoneSoup

soup = BeautifulStoneSoup(open('path/to/file'))

with open('/path/to/output.txt', 'w') as f:
    for i in range(len(soup.findAll('type'))):
        f.write ('%s\t%s\n' % (soup.findAll('type')[i].text, soup.findAll('number')[i].text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/q1/vbgdcffj4wqf34256n43wzz40000gn/T/ipykernel_29303/1177585763.py in <module>
# ----> 1 from BeautifulSoup import BeautifulStoneSoup
#       2
#       3 soup = BeautifulStoneSoup(open('path/to/file'))
#       4
#       5 with open('/path/to/output.txt', 'w') as f:
#
# ModuleNotFoundError: No module named 'BeautifulSoup'
